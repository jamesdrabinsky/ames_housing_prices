# %% [markdown]
# ## Import Modules and Clean Data

# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
np.random.seed(42)

# %%
train = ('./data/train_cleaned.csv')
test = ('./data/test_cleaned.csv')
train_df = pd.read_csv(train, index_col='Id')
test_df = pd.read_csv(test, index_col='Id')

# %% [markdown]
# ## Plotting and Applying Log Transformation to SalePrice

# %%
test_df.head()
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 2658          190        RM          69.0      9142   Pave  Grvl       Reg
# 2718           90        RL          68.0      9662   Pave  None       IR1
# 2414           60        RL          58.0     17104   Pave  None       IR1
# 1989           30        RM          60.0      8520   Pave  None       Reg
# 625            20        RL          68.0      9500   Pave  None       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# Id
# 2658          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 2718          Lvl    AllPub     Inside        Gtl       Sawyer        Norm
# 2414          Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# 1989          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 625           Lvl    AllPub     Inside        Gtl        NAmes        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# Id
# 2658        Norm    2fmCon      2Story             6             8
# 2718        Norm    Duplex      1Story             5             4
# 2414        Norm      1Fam      2Story             7             5
# 1989        Norm      1Fam      1Story             5             6
# 625         Norm      1Fam      1Story             6             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# Id
# 2658        1910            1950      Gable   CompShg      AsbShng
# 2718        1977            1977      Gable   CompShg      Plywood
# 2414        2006            2006      Gable   CompShg      VinylSd
# 1989        1923            2006      Gable   CompShg      Wd Sdng
# 625         1963            1963      Gable   CompShg      Plywood
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# Id
# 2658      AsbShng         None           0.0         TA         Fa      Stone
# 2718      Plywood         None           0.0         TA         TA     CBlock
# 2414      VinylSd         None           0.0         Gd         TA      PConc
# 1989      Wd Sdng         None           0.0         Gd         TA     CBlock
# 625       Plywood      BrkFace         247.0         TA         TA     CBlock
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# Id
# 2658        Fa        TA            No            Unf           0.0
# 2718        Gd        TA            No            Unf           0.0
# 2414        Gd        Gd            Av            GLQ         554.0
# 1989        TA        TA            No            Unf           0.0
# 625         Gd        TA            No            BLQ         609.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# Id
# 2658            Unf           0.0       1020.0         1020.0    GasA
# 2718            Unf           0.0       1967.0         1967.0    GasA
# 2414            Unf           0.0        100.0          654.0    GasA
# 1989            Unf           0.0        968.0          968.0    GasA
# 625             Unf           0.0        785.0         1394.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# Id
# 2658         Gd           N      FuseP         908        1020
# 2718         TA           Y      SBrkr        1967           0
# 2414         Ex           Y      SBrkr         664         832
# 1989         TA           Y      SBrkr         968           0
# 625          Gd           Y      SBrkr        1394           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# Id
# 2658                0         1928             0.0             0.0          2
# 2718                0         1967             0.0             0.0          2
# 2414                0         1496             1.0             0.0          2
# 1989                0          968             0.0             0.0          1
# 625                 0         1394             1.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# Id
# 2658          0              4              2           Fa              9
# 2718          0              6              2           TA             10
# 2414          1              3              1           Gd              7
# 1989          0              2              1           TA              5
# 625           1              3              1           TA              6
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# Id
# 2658        Typ           0         None      Detchd         1910.0
# 2718        Typ           0         None      Attchd         1977.0
# 2414        Typ           1           Gd      Attchd         2006.0
# 1989        Typ           0         None      Detchd         1935.0
# 625         Typ           2           Gd      Attchd         1963.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# Id
# 2658           Unf          1.0        440.0          Po          Po
# 2718           Fin          2.0        580.0          TA          TA
# 2414           RFn          2.0        426.0          TA          TA
# 1989           Unf          2.0        480.0          Fa          TA
# 625            RFn          2.0        514.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# Id
# 2658           Y             0             60             112           0
# 2718           Y           170              0               0           0
# 2414           Y           100             24               0           0
# 1989           N             0              0             184           0
# 625            Y             0             76               0           0
#
#       screen_porch fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# Id
# 2658             0  None         None         0        4     2006       WD
# 2718             0  None         None         0        8     2006       WD
# 2414             0  None         None         0        9     2006       New
# 1989             0  None         None         0        7     2007       WD
# 625            185  None         None         0        7     2009       WD

# %%
plt.hist(train_df["saleprice"], bins =20, color='b')
plt.show()

# %% [markdown]
# This histogram has a positive skew and a long tail.  I am going to apply a log transformation and see whether the SalePrice takes on a more normal distribution.

# %%
train_df['saleprice'] = np.log(train_df['saleprice'])

# %%
plt.hist(train_df["saleprice"], bins =20, color='b')
plt.show()

# %% [markdown]
# This plot looks more like a normal distribution.  One of the assumption of linear regression is distribution normality so I will keep this log transformed SalePrice.

# %% [markdown]
# ##  Correlation

# %% [markdown]
# Below is a heatmap showing the correlation between the numeric features and SalePrice.

# %%
numeric_columns = train_df[train_df.select_dtypes(exclude = object).columns]
corr = numeric_columns.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# While this heatmap is a helpful visual I would like to find the exact correlation between each of the variables.  I will create a matrix showing the correlation between each pair of numeric features and which highlights each cell which has a correlation large than 0.5.

# %%
c = train_df.corr().abs().unstack().sort_values(ascending=False)
c[(c >= 0.5) & (c < 1)]
# Out:
# garage_cars     garage_area       0.896401
# garage_area     garage_cars       0.896401
# year_built      garage_yr_blt     0.846149
# garage_yr_blt   year_built        0.846149
# saleprice       overall_qual      0.826279
# overall_qual    saleprice         0.826279
# totrms_abvgrd   gr_liv_area       0.812397
# gr_liv_area     totrms_abvgrd     0.812397
# 1st_flr_sf      total_bsmt_sf     0.792965
# total_bsmt_sf   1st_flr_sf        0.792965
# gr_liv_area     saleprice         0.713477
# saleprice       gr_liv_area       0.713477
# garage_cars     saleprice         0.682522
# saleprice       garage_cars       0.682522
#                 garage_area       0.673294
# garage_area     saleprice         0.673294
# bedroom_abvgr   totrms_abvgrd     0.664206
# totrms_abvgrd   bedroom_abvgr     0.664206
# total_bsmt_sf   saleprice         0.658320
# saleprice       total_bsmt_sf     0.658320
# bsmt_full_bath  bsmtfin_sf_1      0.657202
# bsmtfin_sf_1    bsmt_full_bath    0.657202
# 2nd_flr_sf      gr_liv_area       0.656673
# gr_liv_area     2nd_flr_sf        0.656673
# garage_yr_blt   year_remod/add    0.643299
# year_remod/add  garage_yr_blt     0.643299
# saleprice       1st_flr_sf        0.631785
# 1st_flr_sf      saleprice         0.631785
# saleprice       year_built        0.631615
# year_built      saleprice         0.631615
# gr_liv_area     full_bath         0.629593
# full_bath       gr_liv_area       0.629593
# year_remod/add  year_built        0.629447
# year_built      year_remod/add    0.629447
# half_bath       2nd_flr_sf        0.615200
# 2nd_flr_sf      half_bath         0.615200
# garage_yr_blt   garage_cars       0.609707
# garage_cars     garage_yr_blt     0.609707
# saleprice       garage_yr_blt     0.608484
# garage_yr_blt   saleprice         0.608484
# saleprice       year_remod/add    0.604411
# year_remod/add  saleprice         0.604411
# overall_qual    year_built        0.602812
# year_built      overall_qual      0.602812
# garage_cars     overall_qual      0.591462
# overall_qual    garage_cars       0.591462
# garage_yr_blt   garage_area       0.590028
# garage_area     garage_yr_blt     0.590028
# year_remod/add  overall_qual      0.583867
# overall_qual    year_remod/add    0.583867
# totrms_abvgrd   2nd_flr_sf        0.581990
# 2nd_flr_sf      totrms_abvgrd     0.581990
# garage_yr_blt   overall_qual      0.580622
# overall_qual    garage_yr_blt     0.580622
# full_bath       saleprice         0.570285
# saleprice       full_bath         0.570285
# overall_qual    garage_area       0.564977
# garage_area     overall_qual      0.564977
# gr_liv_area     overall_qual      0.563871
# overall_qual    gr_liv_area       0.563871
# total_bsmt_sf   overall_qual      0.550993
# overall_qual    total_bsmt_sf     0.550993
# garage_cars     year_built        0.543894
# year_built      garage_cars       0.543894
# gr_liv_area     1st_flr_sf        0.528889
# 1st_flr_sf      gr_liv_area       0.528889
# gr_liv_area     bedroom_abvgr     0.525276
# bedroom_abvgr   gr_liv_area       0.525276
# totrms_abvgrd   full_bath         0.521578
# full_bath       totrms_abvgrd     0.521578
# overall_qual    full_bath         0.514563
# full_bath       overall_qual      0.514563
# saleprice       totrms_abvgrd     0.504458
# totrms_abvgrd   saleprice         0.504458
# 2nd_flr_sf      bedroom_abvgr     0.503371
# bedroom_abvgr   2nd_flr_sf        0.503371
# bsmtfin_sf_1    bsmt_unf_sf       0.501524
# bsmt_unf_sf     bsmtfin_sf_1      0.501524
# dtype: float64

# %% [markdown]
# **Garage Cars**

# %% [markdown]
# I can see that Garage Cars and Garage Area have a very high correlation.  This makes sense since you would expect that a garage would have the requisite amount of room for the cars in it.  I will drop Garage Cars from the dataframe.

# %%
train_df.drop(['garage_cars'], axis=1, inplace=True)

# %%
test_df.drop(['garage_cars'], axis=1, inplace=True)

# %% [markdown]
# **Total SF**

# %% [markdown]
# I am going to add the square footage (SF) columns to get the total area variable.  This will combine all SF columns into one and hopefully reduce multicollinearity.

# %%
train_df['total_area'] = (train_df['total_bsmt_sf'] + train_df['1st_flr_sf'] + train_df['2nd_flr_sf'] + 
                       train_df['low_qual_fin_sf'] + train_df['wood_deck_sf'] + train_df['open_porch_sf'])

# %%
test_df['total_area'] = (test_df['total_bsmt_sf'] + test_df['1st_flr_sf'] + test_df['2nd_flr_sf'] + 
                       test_df['low_qual_fin_sf'] + test_df['wood_deck_sf'] + test_df['open_porch_sf'])

# %% [markdown]
# Now I can drop the individual elements from the Total Area.

# %%
train_df.drop(['total_bsmt_sf', '1st_flr_sf', '2nd_flr_sf',
                       'low_qual_fin_sf', 'wood_deck_sf', 'open_porch_sf'], 
                           axis=1, inplace=True)

# %%
test_df.drop(['total_bsmt_sf', '1st_flr_sf', '2nd_flr_sf',
                       'low_qual_fin_sf', 'wood_deck_sf', 'open_porch_sf'], 
                           axis=1, inplace=True)

# %% [markdown]
# **Total Bath**

# %% [markdown]
# Now I will go through the same process with the columns in the dataframe relating to bathrooms

# %%
train_df.head()
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 109           60        RL          68.0     13517   Pave  None       IR1
# 544           60        RL          43.0     11492   Pave  None       IR1
# 153           20        RL          68.0      7922   Pave  None       Reg
# 318           60        RL          73.0      9802   Pave  None       Reg
# 255           50        RL          82.0     14235   Pave  None       IR1
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# Id
# 109          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 544          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
# 153          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 318          Lvl    AllPub     Inside        Gtl       Timber        Norm
# 255          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# Id
# 109        Norm      1Fam      2Story             6             8        1976
# 544        Norm      1Fam      2Story             7             5        1996
# 153        Norm      1Fam      1Story             5             7        1953
# 318        Norm      1Fam      2Story             5             5        2006
# 255        Norm      1Fam      1.5Fin             6             8        1900
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# Id
# 109            2005      Gable   CompShg      HdBoard      Plywood
# 544            1997      Gable   CompShg      VinylSd      VinylSd
# 153            2007      Gable   CompShg      VinylSd      VinylSd
# 318            2007      Gable   CompShg      VinylSd      VinylSd
# 255            1993      Gable   CompShg      Wd Sdng      Plywood
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# Id
# 109      BrkFace         289.0         Gd         TA     CBlock        TA
# 544      BrkFace         132.0         Gd         TA      PConc        Gd
# 153         None           0.0         TA         Gd     CBlock        TA
# 318         None           0.0         TA         TA      PConc        Gd
# 255         None           0.0         TA         TA      PConc        Fa
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# Id
# 109        TA            No            GLQ         533.0            Unf
# 544        TA            No            GLQ         637.0            Unf
# 153        TA            No            GLQ         731.0            Unf
# 318        TA            No            Unf           0.0            Unf
# 255        Gd            No            Unf           0.0            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf heating heating_qc central_air electrical  \
# Id
# 109           0.0        192.0    GasA         Ex           Y      SBrkr
# 544           0.0        276.0    GasA         Ex           Y      SBrkr
# 153           0.0        326.0    GasA         TA           Y      SBrkr
# 318           0.0        384.0    GasA         Gd           Y      SBrkr
# 255           0.0        676.0    GasA         TA           Y      SBrkr
#
#      gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# Id
# 109         1479             0.0             0.0          2          1
# 544         2122             1.0             0.0          2          1
# 153         1057             1.0             0.0          1          0
# 318         1444             0.0             0.0          2          1
# 255         1445             0.0             0.0          2          0
#
#      bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd functional  \
# Id
# 109              3              1           Gd              6        Typ
# 544              4              1           Gd              8        Typ
# 153              3              1           Gd              5        Typ
# 318              3              1           TA              7        Typ
# 255              3              1           TA              6        Typ
#
#      fireplaces fireplace_qu garage_type  garage_yr_blt garage_finish  \
# Id
# 109           0         None      Attchd         1976.0           RFn
# 544           1           TA      Attchd         1997.0           RFn
# 153           0         None      Detchd         1953.0           Unf
# 318           0         None     BuiltIn         2007.0           Fin
# 255           0         None      Detchd         1957.0           Unf
#
#      garage_area garage_qual garage_cond paved_drive  enclosed_porch  \
# Id
# 109        475.0          TA          TA           Y               0
# 544        559.0          TA          TA           Y               0
# 153        246.0          TA          TA           Y               0
# 318        400.0          TA          TA           Y               0
# 255        484.0          TA          TA           N               0
#
#      3ssn_porch  screen_porch fence misc_feature  misc_val  mo_sold  yr_sold  \
# Id
# 109           0             0  None         None         0        3     2010
# 544           0             0  None         None         0        4     2009
# 153           0             0  None         None         0        1     2010
# 318           0             0  None         None         0        4     2010
# 255           0             0  None         None         0        3     2010
#
#     sale_type  saleprice  total_area
# Id
# 109       WD   11.779129      2248.0
# 544       WD   12.301383      3109.0
# 153       WD   11.599103      2166.0
# 318       WD   12.066811      1928.0
# 255       WD   11.838626      2180.0

# %%
train_df['total_bath'] = (train_df['bsmt_full_bath'] + train_df['full_bath'] + 
                          0.5 * train_df['bsmt_half_bath'] + 0.5 * train_df['half_bath'])

# %%
test_df['total_bath'] = (test_df['bsmt_full_bath'] + test_df['full_bath'] + 
                          0.5 * test_df['bsmt_half_bath'] + 0.5 * test_df['half_bath'])

# %%
train_df.drop(['bsmt_full_bath','full_bath','bsmt_half_bath','half_bath'], axis=1, inplace=True)

# %%
test_df.drop(['bsmt_full_bath','full_bath','bsmt_half_bath','half_bath'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 109           60        RL          68.0     13517   Pave  None       IR1
# 544           60        RL          43.0     11492   Pave  None       IR1
# 153           20        RL          68.0      7922   Pave  None       Reg
# 318           60        RL          73.0      9802   Pave  None       Reg
# 255           50        RL          82.0     14235   Pave  None       IR1
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# Id
# 109          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 544          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
# 153          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 318          Lvl    AllPub     Inside        Gtl       Timber        Norm
# 255          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# Id
# 109        Norm      1Fam      2Story             6             8        1976
# 544        Norm      1Fam      2Story             7             5        1996
# 153        Norm      1Fam      1Story             5             7        1953
# 318        Norm      1Fam      2Story             5             5        2006
# 255        Norm      1Fam      1.5Fin             6             8        1900
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# Id
# 109            2005      Gable   CompShg      HdBoard      Plywood
# 544            1997      Gable   CompShg      VinylSd      VinylSd
# 153            2007      Gable   CompShg      VinylSd      VinylSd
# 318            2007      Gable   CompShg      VinylSd      VinylSd
# 255            1993      Gable   CompShg      Wd Sdng      Plywood
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# Id
# 109      BrkFace         289.0         Gd         TA     CBlock        TA
# 544      BrkFace         132.0         Gd         TA      PConc        Gd
# 153         None           0.0         TA         Gd     CBlock        TA
# 318         None           0.0         TA         TA      PConc        Gd
# 255         None           0.0         TA         TA      PConc        Fa
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# Id
# 109        TA            No            GLQ         533.0            Unf
# 544        TA            No            GLQ         637.0            Unf
# 153        TA            No            GLQ         731.0            Unf
# 318        TA            No            Unf           0.0            Unf
# 255        Gd            No            Unf           0.0            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf heating heating_qc central_air electrical  \
# Id
# 109           0.0        192.0    GasA         Ex           Y      SBrkr
# 544           0.0        276.0    GasA         Ex           Y      SBrkr
# 153           0.0        326.0    GasA         TA           Y      SBrkr
# 318           0.0        384.0    GasA         Gd           Y      SBrkr
# 255           0.0        676.0    GasA         TA           Y      SBrkr
#
#      gr_liv_area  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# Id
# 109         1479              3              1           Gd              6
# 544         2122              4              1           Gd              8
# 153         1057              3              1           Gd              5
# 318         1444              3              1           TA              7
# 255         1445              3              1           TA              6
#
#     functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# Id
# 109        Typ           0         None      Attchd         1976.0
# 544        Typ           1           TA      Attchd         1997.0
# 153        Typ           0         None      Detchd         1953.0
# 318        Typ           0         None     BuiltIn         2007.0
# 255        Typ           0         None      Detchd         1957.0
#
#     garage_finish  garage_area garage_qual garage_cond paved_drive  \
# Id
# 109           RFn        475.0          TA          TA           Y
# 544           RFn        559.0          TA          TA           Y
# 153           Unf        246.0          TA          TA           Y
# 318           Fin        400.0          TA          TA           Y
# 255           Unf        484.0          TA          TA           N
#
#      enclosed_porch  3ssn_porch  screen_porch fence misc_feature  misc_val  \
# Id
# 109               0           0             0  None         None         0
# 544               0           0             0  None         None         0
# 153               0           0             0  None         None         0
# 318               0           0             0  None         None         0
# 255               0           0             0  None         None         0
#
#      mo_sold  yr_sold sale_type  saleprice  total_area  total_bath
# Id
# 109        3     2010       WD   11.779129      2248.0         2.5
# 544        4     2009       WD   12.301383      3109.0         3.5
# 153        1     2010       WD   11.599103      2166.0         2.0
# 318        4     2010       WD   12.066811      1928.0         2.5
# 255        3     2010       WD   11.838626      2180.0         2.0

# %% [markdown]
# **Fireplaces**

# %%
train_df['fireplaces'].value_counts(normalize=True)
# Out:
# 0    0.488748
# 1    0.438356
# 2    0.069961
# 3    0.002446
# 4    0.000489
# Name: fireplaces, dtype: float64

# %% [markdown]
# Approximately 91% of the properties have 0 or 1 fireplaces.  So I will  assign a 1 to properties with a fireplace and a 0 to those without.

# %%
train_df.loc[train_df['fireplaces'] >= 1, 'fireplaces'] = 1

# %%
train_df.loc[train_df['fireplaces'] == 0, 'fireplaces'] = 0

# %%
test_df.loc[test_df['fireplaces'] >= 1, 'fireplaces'] = 1

# %%
test_df.loc[test_df['fireplaces'] == 0, 'fireplaces'] = 0

# %%
train_df.head()
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# Id
# 109           60        RL          68.0     13517   Pave  None       IR1
# 544           60        RL          43.0     11492   Pave  None       IR1
# 153           20        RL          68.0      7922   Pave  None       Reg
# 318           60        RL          73.0      9802   Pave  None       Reg
# 255           50        RL          82.0     14235   Pave  None       IR1
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# Id
# 109          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 544          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
# 153          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 318          Lvl    AllPub     Inside        Gtl       Timber        Norm
# 255          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# Id
# 109        Norm      1Fam      2Story             6             8        1976
# 544        Norm      1Fam      2Story             7             5        1996
# 153        Norm      1Fam      1Story             5             7        1953
# 318        Norm      1Fam      2Story             5             5        2006
# 255        Norm      1Fam      1.5Fin             6             8        1900
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# Id
# 109            2005      Gable   CompShg      HdBoard      Plywood
# 544            1997      Gable   CompShg      VinylSd      VinylSd
# 153            2007      Gable   CompShg      VinylSd      VinylSd
# 318            2007      Gable   CompShg      VinylSd      VinylSd
# 255            1993      Gable   CompShg      Wd Sdng      Plywood
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# Id
# 109      BrkFace         289.0         Gd         TA     CBlock        TA
# 544      BrkFace         132.0         Gd         TA      PConc        Gd
# 153         None           0.0         TA         Gd     CBlock        TA
# 318         None           0.0         TA         TA      PConc        Gd
# 255         None           0.0         TA         TA      PConc        Fa
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# Id
# 109        TA            No            GLQ         533.0            Unf
# 544        TA            No            GLQ         637.0            Unf
# 153        TA            No            GLQ         731.0            Unf
# 318        TA            No            Unf           0.0            Unf
# 255        Gd            No            Unf           0.0            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf heating heating_qc central_air electrical  \
# Id
# 109           0.0        192.0    GasA         Ex           Y      SBrkr
# 544           0.0        276.0    GasA         Ex           Y      SBrkr
# 153           0.0        326.0    GasA         TA           Y      SBrkr
# 318           0.0        384.0    GasA         Gd           Y      SBrkr
# 255           0.0        676.0    GasA         TA           Y      SBrkr
#
#      gr_liv_area  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# Id
# 109         1479              3              1           Gd              6
# 544         2122              4              1           Gd              8
# 153         1057              3              1           Gd              5
# 318         1444              3              1           TA              7
# 255         1445              3              1           TA              6
#
#     functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# Id
# 109        Typ           0         None      Attchd         1976.0
# 544        Typ           1           TA      Attchd         1997.0
# 153        Typ           0         None      Detchd         1953.0
# 318        Typ           0         None     BuiltIn         2007.0
# 255        Typ           0         None      Detchd         1957.0
#
#     garage_finish  garage_area garage_qual garage_cond paved_drive  \
# Id
# 109           RFn        475.0          TA          TA           Y
# 544           RFn        559.0          TA          TA           Y
# 153           Unf        246.0          TA          TA           Y
# 318           Fin        400.0          TA          TA           Y
# 255           Unf        484.0          TA          TA           N
#
#      enclosed_porch  3ssn_porch  screen_porch fence misc_feature  misc_val  \
# Id
# 109               0           0             0  None         None         0
# 544               0           0             0  None         None         0
# 153               0           0             0  None         None         0
# 318               0           0             0  None         None         0
# 255               0           0             0  None         None         0
#
#      mo_sold  yr_sold sale_type  saleprice  total_area  total_bath
# Id
# 109        3     2010       WD   11.779129      2248.0         2.5
# 544        4     2009       WD   12.301383      3109.0         3.5
# 153        1     2010       WD   11.599103      2166.0         2.0
# 318        4     2010       WD   12.066811      1928.0         2.5
# 255        3     2010       WD   11.838626      2180.0         2.0

# %% [markdown]
# ## Create Dummies

# %% [markdown]
# I am going to create dummies for all of the categorical columns in my dataframe.

# %%
train_df = pd.get_dummies(train_df)

# %%
test_df = pd.get_dummies(test_df)

# %%
train_df.shape, test_df.shape
# Out:
# ((2044, 287), (879, 272))

# %% [markdown]
# There is a difference of 15 columns between the train and test dataframes.  I will have to address this before modeling.

# %%
list(set(train_df.columns).difference(test_df.columns))
# Out:
# ['electrical_Mix',
#  'exterior_1st_Stone',
#  'heating_qc_Po',
#  'neighborhood_GrnHill',
#  'roof_matl_Membran',
#  'condition_2_RRAn',
#  'functional_Sev',
#  'neighborhood_Landmrk',
#  'saleprice',
#  'misc_feature_TenC',
#  'exterior_1st_ImStucc',
#  'ms_zoning_A (agr)',
#  'garage_qual_Ex',
#  'utilities_NoSeWa',
#  'condition_2_Artery',
#  'bsmt_cond_Ex',
#  'heating_Wall',
#  'condition_2_RRAe',
#  'condition_2_RRNn',
#  'heating_OthW',
#  'bsmt_cond_Po',
#  'functional_Sal',
#  'exterior_1st_CBlock',
#  'exterior_2nd_Stone']

# %% [markdown]
# **Add Columns to Test Data and Weight as 0**

# %%
test_df['electrical_Mix'] = 0
test_df['neighborhood_Landmrk'] = 0
test_df['ms_zoning_A (agr)'] = 0
test_df['misc_feature_TenC'] = 0
test_df['heating_OthW'] = 0
test_df['bsmt_cond_Po'] = 0
test_df['exterior_1st_Stone'] = 0
test_df['utilities_NoSeWa'] = 0
test_df['functional_Sev'] = 0
test_df['functional_Sal'] = 0
test_df['heating_qc_Po'] = 0
test_df['exterior_1st_CBlock'] = 0
test_df['garage_qual_Ex'] = 0
test_df['heating_Wall'] = 0
test_df['condition_2_Artery'] = 0
test_df['exterior_2nd_Stone'] = 0
test_df['exterior_1st_ImStucc'] = 0
test_df['roof_matl_Membran'] = 0
test_df['bsmt_cond_Ex'] = 0
test_df['condition_2_RRAe'] = 0
test_df['condition_2_RRNn'] = 0
test_df['neighborhood_GrnHill'] = 0
test_df['condition_2_RRAn'] = 0

# %% [markdown]
# ** Drop Rows from Test Data**

# %%
list(set(test_df.columns).difference(train_df.columns))
# Out:
# ['exterior_2nd_PreCast',
#  'exterior_2nd_Other',
#  'exterior_1st_PreCast',
#  'roof_matl_Roll',
#  'sale_type_VWD',
#  'mas_vnr_type_CBlock',
#  'heating_Floor',
#  'kitchen_qual_Po',
#  'roof_matl_Metal']

# %%
test_df.drop(columns=[
    'sale_type_VWD',
    'exterior_1st_PreCast',
    'heating_Floor',
    'roof_matl_Metal',
    'exterior_2nd_Other',
    'exterior_2nd_PreCast',
    'roof_matl_Roll',
    'mas_vnr_type_CBlock',
    'kitchen_qual_Po'], inplace=True)

# %%
train_df.shape
# Out:
# (2044, 287)

# %%
test_df.shape
# Out:
# (879, 286)

# %% [markdown]
# I see that the train dataset has one more column (SalePrice) than the test dataset.  I will move onto modeling.

# %% [markdown]
# ## Exported Data Sets for Modeling

# %%
train_df.to_csv('./data/train_modeling.csv')
test_df.to_csv('./data/test_modeling.csv')

# %%
train_df.shape, test_df.shape
# Out:
# ((2044, 287), (879, 286))
